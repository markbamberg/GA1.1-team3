# %%
def add(a,b):
    return a + b

print(add(1,2))
print(add(3,2))
print(add(4,2))

# %%
def sum_list(values):
    total = 0
    
    for number in values:
        total = add(total, number)
    return total

print(sum_list([1,5,8,7]))
